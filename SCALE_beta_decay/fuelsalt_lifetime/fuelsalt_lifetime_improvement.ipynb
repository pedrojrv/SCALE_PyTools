# %%
import pandas as pd
import matplotlib.pyplot as plt

import sys

sys.path.append("..")

# %%
import pyscale.lifetime_imp_plot as life_plot

# %%
msre = pd.read_csv("MSRE_K_imp.csv")
msbr = pd.read_csv("MSBR_K_imp.csv")
msdr = pd.read_csv("MSDR_K_imp.csv")

# %%
msre
# Out:
#    Efficiency         Day  Improvement
# 0           0  572.500000     0.000000
# 1           5  609.161144     0.064037
# 2          10  633.945006     0.107328
# 3          12  639.122211     0.116371
# 4          15  644.677105     0.126074
# 5          20  650.662105     0.136528
# 6          40  660.555195     0.153808
# 7          60  664.112143     0.160021
# 8          80  665.944927     0.163223
# 9         100  667.068081     0.165184

# %%
life_plot.lifetime_efficiency_plot(msre)

# %%
life_plot.lifetime_eff_all_plot(msre, msbr, msdr)
