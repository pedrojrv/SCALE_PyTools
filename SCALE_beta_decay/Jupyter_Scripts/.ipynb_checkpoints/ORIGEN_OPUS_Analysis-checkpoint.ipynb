# %% [markdown]
# # Importing Modules

# %%
import pandas as pd
import numpy as np
from decimal import Decimal
import matplotlib.pyplot as plt

# %% [markdown]
# # Setting path for analysis

# %%
path = "./Apollo/MSDR/MSDR_beta.000000000000000000.plt"
path2 = "./Apollo/MSDR/MSDR_beta.000000000000000001.plt"

# %%
df = pd.read_csv(path, sep="\s+", skiprows=5)
df2 = pd.read_csv(path2, sep="\s+", skiprows=5)

# %%
df_testing.head()
# Out:
#         time      u238       f19      li7         nd144         ba138  \
# 0  0.000e+00  950000.0  530000.0  77750.0  8.157000e-13  7.817000e-13
# 1  3.000e+02  901700.0  529900.0  77740.0  8.931000e+02  2.173000e+03
# 2  6.667e+02  833200.0  529900.0  77720.0  3.316000e+03  4.635000e+03
# 3  1.033e+03  761400.0  529800.0  77710.0  6.179000e+03  7.051000e+03
# 4  1.400e+03  691300.0  529800.0  77700.0  9.145000e+03  9.455000e+03
#
#           ce140         cs137         pu239         la139  ...         gd148  \
# 0  7.930000e-13  7.760000e-13  1.355000e-12  7.873000e-13  ...  0.000000e+00
# 1  1.958000e+03  2.112000e+03  8.889000e+03  2.026000e+03  ...  4.120000e-73
# 2  4.284000e+03  4.587000e+03  1.102000e+04  4.216000e+03  ...  0.000000e+00
# 3  6.614000e+03  6.986000e+03  1.254000e+04  6.292000e+03  ...  0.000000e+00
# 4  8.982000e+03  9.319000e+03  1.360000e+04  8.302000e+03  ...  0.000000e+00
#
#           eu146         gd146        tb154m         tb154         eu145  \
# ...

# %%
df_testing2
# Out:
#          time         cs135         xe134         xe136         cs133  \
# 0   0.000e+00  2.240000e-18  2.224000e-18  2.257000e-18  2.207000e-18
# 1   3.000e+02  2.109000e+03  2.373000e+03  2.143000e+03  2.012000e+03
# 2   6.667e+02  5.175000e+03  5.337000e+03  4.925000e+03  4.504000e+03
# 3   1.033e+03  8.250000e+03  8.256000e+03  7.679000e+03  6.959000e+03
# 4   1.400e+03  1.133000e+04  1.116000e+04  1.040000e+04  9.394000e+03
# 5   1.767e+03  1.440000e+04  1.405000e+04  1.309000e+04  1.181000e+04
# 6   2.133e+03  1.746000e+04  1.692000e+04  1.577000e+04  1.422000e+04
# 7   2.500e+03  2.050000e+04  1.979000e+04  1.843000e+04  1.661000e+04
# 8   2.867e+03  2.353000e+04  2.265000e+04  2.109000e+04  1.900000e+04
# 9   3.233e+03  2.651000e+04  2.549000e+04  2.375000e+04  2.136000e+04
# 10  3.600e+03  2.945000e+04  2.832000e+04  2.643000e+04  2.372000e+04
#
#            xe131          kr86         xe132          kr84         xe130  ...  \
# ...

# %%
df_testing = df.copy()
df_testing2 = df2.copy()

# %%
df_testing = df_testing.transpose()
df_testing2 = df_testing2.transpose()

# %%
df_testing.reset_index(level=0, inplace=True)
df_testing2.reset_index(level=0, inplace=True)

# %%
df_testing = df_testing.rename(columns = {'index':'time'})
df_testing2 = df_testing2.rename(columns = {'index':'time'})

# %%
df_testing.iloc[:,1:] = df_testing.iloc[:,1:].mul(62.1)
df_testing2.iloc[:,1:] = df_testing2.iloc[:,1:].mul(62.1)

# %%
ax = df_testing2.plot(x="time", y="xe135", figsize=(10,8), title="Concentration vs Time")
ax.set_xlabel("Time (days)")
ax.set_ylabel("U-238 (g)")
# Out:
# Text(0, 0.5, 'U-238 (g)')

# %%
isotopes = list(df_testing2.columns)
isotopes.pop(0)
num_isotopes = len(isotopes)
print("There are {} isotopes in Mixture 7.".format(num_isotopes))
# Out:
# There are 458 isotopes in Mixture 7.

# %%
# ax = df.iloc[0:252, [0,2]].plot('Group No', 'Critical Flux', figsize=(14, 12), legend=None, ylim=(0, 0.010))
# plt.gca().invert_xaxis()
for i in range(1, num_isotopes):    
    isotope = isotopes[i]

    fig, ax1 = plt.subplots(figsize=(10,8))

    color = 'tab:red'
    ax1.set_xlabel('time (s)')
    ax1.set_ylabel('Mixture 1 (grams)', color=color)
    ax1.set_title(isotope)
    ax1.plot(df_testing['time'], df_testing[isotope], color=color)
    ax1.tick_params(axis='y', labelcolor=color)

    ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

    color = 'tab:blue'
    ax2.set_ylabel('Mixture 7 (grams)', color=color)  # we already handled the x-label with ax1
    ax2.plot(df_testing2['time'], df_testing2[isotope], color=color)
    ax2.tick_params(axis='y', labelcolor=color)

    fig.tight_layout()  # otherwise the right y-label is slightly clipped
    plt.savefig("./Images/" + isotope + ".png")
    plt.close()

# %%
# isotope = "xe135"

# fig, ax1 = plt.subplots(figsize=(10,8))

# color = 'tab:red'
# ax1.set_xlabel('time (s)')
# ax1.set_ylabel('Mixture 1', color=color)
# ax1.plot(df_testing['time'], df_testing[isotope], color=color)
# ax1.tick_params(axis='y', labelcolor=color)

# ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

# color = 'tab:blue'
# ax2.set_ylabel('Mixture 7', color=color)  # we already handled the x-label with ax1
# ax2.plot(df_testing2['time'], df_testing2[isotope], color=color)
# ax2.tick_params(axis='y', labelcolor=color)

# fig.tight_layout()  # otherwise the right y-label is slightly clipped
# plt.show()
